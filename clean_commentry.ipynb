# %%
import pandas as pd

# %%
df=pd.read_csv('files/2023/gt-vs-dc-44th-match-indian-premier-league-2023.csv')
commentry=df['Commentary Text']
print(commentry.tail(10))
# Out:
# 238     Ishant to Shubman Gill, no run, good length b...
# 239     Ishant to Shubman Gill, no run, back of a len...
# 240     Ishant to Shubman Gill, no run, good length b...
# 241     Ishant to Shubman Gill, no run, good length b...
# 242     Khaleel Ahmed to Saha, out Caught by Philip S...
# 243     Khaleel Ahmed to Saha, no run, good length ba...
# 244     Khaleel Ahmed to Saha, no run, full ball just...
# 245     Khaleel Ahmed to Saha, no run, that was poor ...
# 246     Khaleel Ahmed to Saha, no run, Khaleel Ahmed ...
# 247     Khaleel Ahmed to Saha, no run, Khaleel Ahmed ...
# Name: Commentary Text, dtype: object

# %%
def bowler_and_batsman(comment):
    return comment.split(',')[0].split('to')

comment=df['Commentary Text'][100]
bowler_and_batsman(comment=comment)
# Out:
# [' Joshua Little ', ' Priyam Garg']

# %%
deliveries = [
    "Fast",
    "Slow",
    "Bouncer",
    "Inswing",
    "Outswing",
    "Cutter",
    "Spinner",
    "Googly",
    "Flipper",
    "Topspin",
    "Arm Ball",
    "Carrom Ball",
    "Reverse Swing",
    "Slider",
    "Knuckleball",
    "Beamer",
    "Yorker",
    "Slower Ball",
    "Leg Break",
    "Back-of-the-Hand",
    "Slingy Action",
    "Double Bouncer"
]

# %%
deliveries=['Bouncer','Inswinger','Reverse swing','Leg cutter','Off cutter','Outswinger','Yorker','Beamer','Knuckleball','Slower ball','full','short']
def ball_type(comment):
    for ball in deliveries:
        if ball.casefold() in comment:
            print(ball)
a=df['Commentary Text'][40]
ball_type(a)

# %%
balls=[]
def runs(comment):
    extra=None
    run=comment.split(',')[1]
    balls.append(run)
    print(run)
    if '1 run'.casefold() in run:
        run = 1
    elif '2 runs'.casefold() in run:
        run= 2
    elif 'no run'.casefold() in run:
        run= 0
    elif '3 runs'.casefold() in run:
        run = 3
    elif 'Four'.casefold() in run:
        run =4
    elif 'Six'.casefold() in run:
        run =6
    elif 'byes'.casefold() in run:
        run=comment.split(',')[2]
    elif 'out'.casefold() in run:
        run='Out'
    elif 'wides'.casefold() in run:
        if run.split(' ')[1]:
            extra=run.split(' ')[1]
            run='Wide'
        else:
            run='Wide'
    
    
    return run,extra
for j,i in enumerate(commentry):
    print(j,list(runs(i)))
# Out:
#  no run
# 0 [0, None]
#  out Caught by Hardik Pandya!! 100th IPL wicket for Mohit Sharma! Back of the hand slower ball outside off
# 1 ['Out', None]
#  1 run
# 2 [1, None]
#  no run
# 3 [0, None]
#  1 run
# 4 [1, None]
#  1 run
# 5 [1, None]
#  1 run
# 6 [1, None]
#  no run
# 7 [0, None]
#  no run
# 8 [0, None]
#  out Caught by Abhinav Manohar!! Rashid Khan gets his first wicket! Tossed up leg spinner around leg stump
# 9 ['Out', None]
#  1 run
# 10 [1, None]
#  SIX
# 11 [' SIX', None]
#  no run
# 12 [0, None]
#  1 run
# 13 [1, None]
#  1 run
# 14 [1, None]
#  2 runs
# 15 [2, None]
#  SIX
# 16 [' SIX', None]
#  2 runs
# 17 [2, None]
#  FOUR
# 18 [' FOUR', None]
#  2 runs
# 19 [2, None]
#  1 run
# 20 [1, None]
#  FOUR
# 21 [' FOUR', None]
#  1 run
# 22 [1, None]
#  FOUR
# 23 [' FOUR', None]
#  1 run
# 24 [1, None]
#  1 run
# 25 [1, None]
#  SIX
# 26 [' SIX', None]
#  no run
# 27 [0, None]
#  FOUR
# 28 [' FOUR', None]
#  1 run
# 29 [1, None]
#  1 run
# 30 [1, None]
#  wide
# 31 [' wide', None]
#  no run
# 32 [0, None]
#  1 run
# 33 [1, None]
#  2 runs
# 34 [2, None]
#  no run
# 35 [0, None]
#  no run
# 36 [0, None]
#  out Caught by Rashid Khan!! Axar departs after a cameo! Mohit Sharma bowls a good length ball on off. Axar goes through with his lofted shot but only manages to get it off the toe-end of his bat. The ball skies down the ground. Rashid Khan from long-off moves to his left
# 37 ['Out', None]
#  no run
# 38 [0, None]
#  2 runs
# 39 [2, None]
#  1 run
# 40 [1, None]
#  1 run
# 41 [1, None]
#  1 run
# 42 [1, None]
#  1 run
# 43 [1, None]
#  no run
# 44 [0, None]
#  no run
# 45 [0, None]
#  1 run
# 46 [1, None]
#  FOUR
# 47 [' FOUR', None]
#  1 run
# 48 [1, None]
#  1 run
# 49 [1, None]
#  no run
# 50 [0, None]
#  1 run
# 51 [1, None]
#  leg byes
# 52 [' 1 run', None]
#  no run
# 53 [0, None]
#  no run
# 54 [0, None]
#  1 run
# 55 [1, None]
#  2 runs
# 56 [2, None]
#  no run
# 57 [0, None]
#  no run
# 58 [0, None]
#  no run
# 59 [0, None]
#  1 run
# 60 [1, None]
#  1 run
# 61 [1, None]
#  SIX
# 62 [' SIX', None]
#  wide
# 63 [' wide', None]
#  1 run
# 64 [1, None]
#  no run
# 65 [0, None]
#  1 run
# 66 [1, None]
#  no run
# 67 [0, None]
#  1 run
# 68 [1, None]
#  no run
# 69 [0, None]
#  no run
# 70 [0, None]
#  no run
# 71 [0, None]
#  wide
# 72 [' wide', None]
#  1 run
# 73 [1, None]
#  1 run
# 74 [1, None]
#  no run
# 75 [0, None]
#  SIX
# 76 [' SIX', None]
#  no run
# 77 [0, None]
#  1 run
# 78 [1, None]
#  no run
# 79 [0, None]
#  1 run
# 80 [1, None]
#  no run
# 81 [0, None]
#  no run
# 82 [0, None]
#  FOUR
# 83 [' FOUR', None]
#  no run
# 84 [0, None]
#  no run
# 85 [0, None]
#  no run
# 86 [0, None]
#  FOUR
# 87 [' FOUR', None]
#  no run
# 88 [0, None]
#  no run
# 89 [0, None]
#  no run
# 90 [0, None]
#  no run
# 91 [0, None]
#  1 run
# 92 [1, None]
#  out Caught by Saha!! The Delhi Capitals have an early flight to catch? Looks like it. Mohammed Shami has four. What a game he's having. Full and swinging away in the outside off channel
# 93 [4, None]
#  1 run
# 94 [1, None]
#  no run
# 95 [0, None]
#  no run
# 96 [0, None]
#  no run
# 97 [0, None]
#  out Caught by Saha!! Mohammed Shami is on a roll. And so is Saha. He has taken a wonderful catch. The upright seam magic once again. It curves in from a length
# 98 ['Out', None]
#  2 runs
# 99 [2, None]
#  2 runs
# 100 [2, None]
#  1 run
# 101 [1, None]
#  no run
# 102 [0, None]
#  1 run
# 103 [1, None]
#  no run
# 104 [0, None]
#  no run
# 105 [0, None]
#  out Caught by Saha!! Absolute corker. Test match bowling
# 106 ['Out', None]
#  no run
# 107 [0, None]
#  1 run
# 108 [1, None]
#  no run
# 109 [0, None]
#  no run
# 110 [0, None]
#  FOUR
# 111 [' FOUR', None]
#  FOUR
# 112 [' FOUR', None]
#  no run
# 113 [0, None]
#  no run
# 114 [0, None]
#  1 run
# 115 [1, None]
#  no ball
# 116 [' no ball', None]
#  no run
# 117 [0, None]
#  no run
# 118 [0, None]
#  2 runs
# 119 [2, None]
#  3 runs
# 120 [3, None]
#  no run
# 121 [0, None]
#  no run
# 122 [0, None]
#  out Caught by Miller!! Golden duck for Philip Salt. What a horrid start for DC. A gentle full outswinging teaser outside off
# 123 ['Out', None]
#  1 run
# 124 [1, None]
#  2 runs
# 125 [2, None]
#  out Caught by Rossouw!! Not to be Tewatia's night!! Full props to Ishant Sharma who puzzles the batter by going into the deck onto off
# 126 ['Out', None]
#  no run
# 127 [0, None]
#  1 run
# 128 [1, None]
#  2 runs
# 129 [2, None]
#  SIX
# 130 [' SIX', None]
#  SIX
# 131 [' SIX', None]
#  SIX
# 132 [' SIX', None]
#  1 run
# 133 [1, None]
#  2 runs
# 134 [2, None]
#  no run
# 135 [0, None]
#  1 run
# 136 [1, None]
#  1 run
# 137 [1, None]
#  1 run
# 138 [1, None]
#  no run
# 139 [0, None]
#  1 run
# 140 [1, None]
#  out Caught by Aman Hakim Khan!! Abhinav Manohar's laboured innings comes to an end. He just wasn't timing them tonight... This was a slower length ball at the stumps
# 141 ['Out', None]
#  1 run
# 142 [1, None]
#  1 run
# 143 [1, None]
#  1 run
# 144 [1, None]
#  no run
# 145 [0, None]
#  1 run
# 146 [1, None]
#  1 run
# 147 [1, None]
#  2 runs
# 148 [2, None]
#  1 run
# 149 [1, None]
#  1 run
# 150 [1, None]
#  no run
# 151 [0, None]
#  FOUR
# 152 [' FOUR', None]
#  1 run
# 153 [1, None]
#  wide
# 154 [' wide', None]
#  1 run
# 155 [1, None]
#  1 run
# 156 [1, None]
#  1 run
# 157 [1, None]
#  1 run
# 158 [1, None]
#  FOUR
# 159 [' FOUR', None]
#  no run
# 160 [0, None]
#  1 run
# 161 [1, None]
#  FOUR
# 162 [' FOUR', None]
#  1 run
# 163 [1, None]
#  no run
# 164 [0, None]
#  1 run
# 165 [1, None]
#  1 run
# 166 [1, None]
#  no run
# 167 [0, None]
#  1 run
# 168 [1, None]
#  1 run
# 169 [1, None]
#  no run
# 170 [0, None]
#  1 run
# 171 [1, None]
#  1 run
# 172 [1, None]
#  1 run
# 173 [1, None]
#  no run
# 174 [0, None]
#  1 run
# 175 [1, None]
#  1 run
# 176 [1, None]
#  no run
# 177 [0, None]
#  1 run
# 178 [1, None]
#  1 run
# 179 [1, None]
#  no run
# 180 [0, None]
#  1 run
# 181 [1, None]
#  2 wides
# 182 ['Wide', '2']
#  1 run
# 183 [1, None]
#  no run
# 184 [0, None]
#  1 run
# 185 [1, None]
#  no run
# 186 [0, None]
#  no run
# 187 [0, None]
#  2 runs
# 188 [2, None]
#  1 run
# 189 [1, None]
#  wide
# 190 [' wide', None]
#  no run
# 191 [0, None]
#  SIX
# 192 [' SIX', None]
#  1 run
# 193 [1, None]
#  no run
# 194 [0, None]
#  1 run
# 195 [1, None]
#  1 run
# 196 [1, None]
#  no run
# 197 [0, None]
#  1 run
# 198 [1, None]
#  no run
# 199 [0, None]
#  no run
# 200 [0, None]
#  no run
# 201 [0, None]
#  1 run
# 202 [1, None]
#  1 run
# 203 [1, None]
#  no run
# 204 [0, None]
#  1 run
# 205 [1, None]
#  no run
# 206 [0, None]
#  out Bowled!! Knocked over!! A very unlike David Miller type shot so early on
# 207 ['Out', None]
#  no run
# 208 [0, None]
#  1 run
# 209 [1, None]
#  no run
# 210 [0, None]
#  no run
# 211 [0, None]
#  1 run
# 212 [1, None]
#  no run
# 213 [0, None]
#  FOUR
# 214 [' FOUR', None]
#  no run
# 215 [0, None]
#  no run
# 216 [0, None]
#  out Bowled!! GT are 3 wickets down inside the powerplay and it's game on! Brilliant deception from Ishant and Warner is pumped up. He bowls a knuckle ball on a fuller length in line of the stumps. Shankar tries to flick it across but is through his shot early. Ends up getting beaten and the ball crashes into middle and off. Shankar b Ishant 6(9) [4s-1]
# 217 ['Out', None]
#  no run
# 218 [0, None]
#  no run
# 219 [0, None]
#  FOUR
# 220 [' FOUR', None]
#  1 run
# 221 [1, None]
#  no run
# 222 [0, None]
#  2 runs
# 223 [2, None]
#  no run
# 224 [0, None]
#  no run
# 225 [0, None]
#  wide
# 226 [' wide', None]
#  no run
# 227 [0, None]
#  no run
# 228 [0, None]
#  out Caught by Manish Pandey!! Shubman Gill falls cheaply! The DC players are cock-a-hoop as Nortje strikes off his first ball. He pitches it up and bowls it well outside off
# 229 ['Out', None]
#  no run
# 230 [0, None]
#  FOUR
# 231 [' FOUR', None]
#  FOUR
# 232 [' FOUR', None]
#  no run
# 233 [0, None]
#  FOUR
# 234 [' FOUR', None]
#  no run
# 235 [0, None]
#  FOUR
# 236 [' FOUR', None]
#  2 runs
# 237 [2, None]
#  no run
# 238 [0, None]
#  no run
# 239 [0, None]
#  no run
# 240 [0, None]
#  no run
# 241 [0, None]
#  out Caught by Philip Salt!! Saha was looking all at sea against Khaleel Ahmed and he eventually departs! He flirted with danger in the third ball of the over but survived. But
# 242 ['Out', None]
#  no run
# 243 [0, None]
#  no run
# 244 [0, None]
#  no run
# 245 [0, None]
#  no run
# 246 [0, None]
#  no run
# 247 [0, None]

# %%
set(balls)
# Out:
# {' 1 run',
#  ' 2 runs',
#  ' 2 wides',
#  ' 3 runs',
#  ' FOUR',
#  ' SIX',
#  ' leg byes',
#  ' no ball',
#  ' no run',
#  " out Bowled!! GT are 3 wickets down inside the powerplay and it's game on! Brilliant deception from Ishant and Warner is pumped up. He bowls a knuckle ball on a fuller length in line of the stumps. Shankar tries to flick it across but is through his shot early. Ends up getting beaten and the ball crashes into middle and off. Shankar b Ishant 6(9) [4s-1]",
#  ' out Bowled!! Knocked over!! A very unlike David Miller type shot so early on',
#  ' out Caught by Abhinav Manohar!! Rashid Khan gets his first wicket! Tossed up leg spinner around leg stump',
#  " out Caught by Aman Hakim Khan!! Abhinav Manohar's laboured innings comes to an end. He just wasn't timing them tonight... This was a slower length ball at the stumps",
#  ' out Caught by Hardik Pandya!! 100th IPL wicket for Mohit Sharma! Back of the hand slower ball outside off',
#  ' out Caught by Manish Pandey!! Shubman Gill falls cheaply! The DC players are cock-a-hoop as Nortje strikes off his first ball. He pitches it up and bowls it well outside off',
#  ' out Caught by Miller!! Golden duck for Philip Salt. What a horrid start for DC. A gentle full outswinging teaser outside off',
#  ' out Caught by Philip Salt!! Saha was looking all at sea against Khaleel Ahmed and he eventually departs! He flirted with danger in the third ball of the over but survived. But',
#  ' out Caught by Rashid Khan!! Axar departs after a cameo! Mohit Sharma bowls a good length ball on off. Axar goes through with his lofted shot but only manages to get it off the toe-end of his bat. The ball skies down the ground. Rashid Khan from long-off moves to his left',
#  " out Caught by Rossouw!! Not to be Tewatia's night!! Full props to Ishant Sharma who puzzles the batter by going into the deck onto off",
#  ' out Caught by Saha!! Absolute corker. Test match bowling',
#  ' out Caught by Saha!! Mohammed Shami is on a roll. And so is Saha. He has taken a wonderful catch. The upright seam magic once again. It curves in from a length',
#  " out Caught by Saha!! The Delhi Capitals have an early flight to catch? Looks like it. Mohammed Shami has four. What a game he's having. Full and swinging away in the outside off channel",
#  ' wide'}

# %%
def check():
    for i in df['Commentary Text']:
        if 'no ball'.casefold()in i:
            print(i,'\n\n')
check()
# Out:
# Hardik Pandya to Priyam Garg, no ball, out Warner Run Out!! It's getting bad to worse for DC. Priyam Garg showed a bit of intent to take a single the previous delivery but didn't get the desired response from his partner and this time he flicks it straight to Rashid to short mid-wicket. Called for a quick single and didn't move. Warner had committed and never stopped. Kept running to the striker's end and by the time he saw his partner, he was left stranded in the middle of the pitch. Rashid smartly decides against the throw and runs towards the stumps to effect the easiest of run-outs. Amidst all the drama, it has been deemed a front foot no ball... Warner run out (Rashid Khan) 2(2)
